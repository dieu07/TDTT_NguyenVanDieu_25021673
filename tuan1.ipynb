# %%
print("Hello World!")

# %%
name = input("Nhập tên của bạn:")
print("Xin chào",name)

# %%
a = int(input("Nhập số a:"))
b = int(input("Nhập số b:"))
print("Tổng:",a + b,
      ", Hiệu:",a - b,
      ", Tích:",a * b,
      ", Phần nguyên a chia cho b:",a//b,
      ", Phần dư a chia cho b:",a % b,
      ", Kết quả a chia cho b (lấy 2 chữ số thập phân):", f"{a/b:.2f}")

# %%
nums = list(map(float,input("Nhập 6 đầu điểm theo thứ tự:").split()))
tb = (((nums[0]+nums[1]+nums[2])+(nums[3]+nums[4])*2 + nums[5]*3)/10)
print(f"Điểm trung bình là:{tb:.1f}")

# %%
a,b = map(int,input("Nhập hai số a và b:").split())
print("Kết quả a mũ b là:",a ** b)

# %%
ch = input("Nhập kí tự thường a-z:")
print("Mã Unicode là:",ord(ch))
inhoa = chr(ord(ch)-32) #chữ thường cách hoa 32 đơn vị
print("Chữ viết hoa là:",inhoa)

# %%
A = ((13**2)*3) + 5
B = 13**2*3 + 5
print(A,B)
# Thứ tự ưu tiên trong các phép toán

# %%
C = float(input("Nhập độ C (°):"))
F = 9/5*C + 32
print("Nhiệt độ F là:",f"{F:.2f}")

# %%
gia = float(input("Giá đồng hồ (USD) là:"))
ship = 10
nc = gia * 30 / 100
VAT = gia * 10 /100
print("Tổng chi phí phải trả là:",f"{gia+ship+nc+VAT:.2f}","USD")

# %%
names = input("Nhập 3 tên:").split()
names.reverse()
print(f"Hi {names[0]}, {names[1]} and {names[2]}.")

# %%
a , b = map(float,input("Nhập số giờ và số phút, cách nhau bằng khoảng trắng:").split())
gio = a * 60 * 60
phut = b * 60
print("Số giây là:",gio+phut)

# %%
n = int(input("Nhập độ dài cạnh Rubik:"))
tong = n * n * 6
print("Tổng số miếng dán riêng lẻ là:",tong)

# %%
a = int(input("Nhập số a:"))
b = int(input("Nhập số b:"))
x = a * b
print("Hàng đơn vị của tích là:",x % 10)

# %%
a, b = map(int,input("Nhập hai số a và b:").split())
a = a + b
b = a - b
a = a - b
print("Hoán đổi a =",a,",b =",b)

# %%
n = int(input("Nhập số nguyên dương n: "))
sosao = 6 * n * (n - 1) + 1
print(sosao)

# %%
print("Spring")
print("Summer")
print("Autumn")
print("Winter")
print("Spring\nSummer\nAutumn\nWinter")
print("""Spring
Summer
Autumn
Winter""")
seasons = ["Spring", "Summer", "Autumn", "Winter"]
for season in seasons:
    print(season)

# %%
print("""
  *
 ***
*****""")

# %%
print("""
### ##  ### ###
 #  # #  #   #
 #  # #  #   #
 #  # #  #   #
 #  ##   #   # """)

# %%
print("""Monday
Tuesday
Wednesday
Thursday
Friday
Saturday
Sunday""")
import calendar
for i in range (7):
    print(calendar.day_name[i])

# %%
import calendar
for i in range(1, 13):
    print(calendar.month_name[i])

# %%
print("Hello, world\n" * 10)
